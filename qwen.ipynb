# %% [markdown]
# # Qwen Quickstart Notebook
#
# This notebook is sourced from the official QwenLM/Qwen repository.
#
# **Original location:** [recipes/quickstart/qwen.ipynb](https://github.com/QwenLM/Qwen/blob/main/recipes/quickstart/qwen.ipynb)
#
# Please refer to the original notebook for the latest version and full content.
#
# ## Getting Started
#
# To use the full notebook, download it directly:
# ```bash
# curl -O https://raw.githubusercontent.com/QwenLM/Qwen/main/recipes/quickstart/qwen.ipynb
# ```
#
# ## About Qwen
#
# Qwen is a large language model series developed by Alibaba Cloud. The official repository contains:
# - Model weights and configurations
# - Fine-tuning scripts
# - Example notebooks and demos
# - Evaluation tools
#
# For more information, visit: https://github.com/QwenLM/Qwen
